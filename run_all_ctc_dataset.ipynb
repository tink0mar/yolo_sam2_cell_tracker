# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")

# %%
from run_ctc_yolo_sam2_video_pipeline import run_sam2_yolo_pipeline

dataset_folders = [
    "DIC-C2DH-HeLa",
    #"Fluo-C2DL-Huh7",
    #"Fluo-C2DL-MSC",
    #"Fluo-N2DH-GOWT1",
    #"Fluo-N2DH-SIM",
    #"PhC-C2DH-U373",
    #"Fluo-N2DL-HeLa",
    #"BF-C2DL-MuSC",
    #"PhC-C2DL-PSC",
    #"BF-C2DL-HSC",
]

generate_images = True

for dataset in dataset_folders:
    for seq in ["01", "02"]:
        dataset_folder = f"./data/{dataset}/{seq}"
        track_folder = f"./data/{dataset}/{seq}_RES"
        print(f"=== {dataset} / {seq} ===")
        run_sam2_yolo_pipeline(dataset_folder, track_folder,generate_images)
# Out:
# === DIC-C2DH-HeLa / 01 ===
# Converted TIFs in './data/DIC-C2DH-HeLa/01' to JPGs in './DIC-C2DH-HeLa-01-tmp'
# frame loading (JPEG): 100%|█████████████████████| 84/84 [00:02<00:00, 34.90it/s]
# /home/xkozak6/yolo_sam2__cell_tracker_pipeline/sam2/sam2_yolo_video_cell_tracker.py:891: UserWarning: cannot import name '_C' from 'sam2' (/home/xkozak6/yolo_sam2__cell_tracker_pipeline/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(
# propagate reverse (YOLO-assisted): 100%|████████| 84/84 [01:57<00:00,  1.40s/it]
# Saved 84 overlay frames to ./data/DIC-C2DH-HeLa/01_no_remap_labeled_video
# Saved 84 overlay frames to ./data/DIC-C2DH-HeLa/01_labeled_video
#
# ...
